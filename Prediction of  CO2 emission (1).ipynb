# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import warnings
warnings.filterwarnings("ignore")

# %%
train_df = pd.read_csv('train_data.csv')
test_df = pd.read_csv('test_data.csv')

# %%
train_df.head()
# Out:
#             Make                   Model Vehicle Class  Engine Size(L)  \
# 0      CHEVROLET                TRAX 4WD   SUV - SMALL             1.4
# 1           FORD                 MUSTANG    SUBCOMPACT             5.8
# 2  MERCEDES-BENZ            E 400 4MATIC      MID-SIZE             3.0
# 3         JAGUAR                     XFR      MID-SIZE             5.0
# 4          DODGE  CHALLENGER SRT HELLCAT      MID-SIZE             6.2
#
#    Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4          AS6         X                               9.9
# 1          8           M6         Z                              15.9
# 2          6           A9         Z                              11.8
# 3          8          AS8         E                              21.3
# 4          8           A8         Z                              18.0
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# ...

# %% [markdown]
# **Data Information and Description:**

# %%
train_df.shape
# Out:
# (5760, 12)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              5760 non-null   object
#  1   Model                             5760 non-null   object
#  2   Vehicle Class                     5760 non-null   object
#  3   Engine Size(L)                    5760 non-null   float64
#  4   Cylinders                         5760 non-null   int64
#  5   Transmission                      5760 non-null   object
#  6   Fuel Type                         5760 non-null   object
#  7   Fuel Consumption City (L/100 km)  5760 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   5760 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  5760 non-null   float64
#  10  Fuel Consumption Comb (mpg)       5760 non-null   int64
# ...

# %%
train_df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     5760.000000  5760.000000                       5760.000000
# mean         3.169583     5.629688                         12.580295
# std          1.361186     1.840446                          3.511501
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                       5760.00000                       5760.000000
# mean                           9.05283                         10.993177
# std                            2.22131                          2.897138
# ...

# %%
train_df.skew()
# Out:
# Engine Size(L)                      0.804320
# Cylinders                           1.123640
# Fuel Consumption City (L/100 km)    0.822347
# Fuel Consumption Hwy (L/100 km)     1.084502
# Fuel Consumption Comb (L/100 km)    0.903184
# Fuel Consumption Comb (mpg)         0.974357
# CO2 Emissions(g/km)                 0.535407
# dtype: float64

# %% [markdown]
# **EDA:**

# %%
sns.distplot(train_df['CO2 Emissions(g/km)'])
# Out:
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Density'>

# %%
sns.distplot(train_df['Fuel Consumption City (L/100 km)'])
# Out:
# <AxesSubplot:xlabel='Fuel Consumption City (L/100 km)', ylabel='Density'>

# %%
fig = plt.figure(figsize = [15, 8])
sns.countplot(x = 'Vehicle Class', data = train_df, palette = ['#DB5E56','#56DB7F'])
plt.xticks(rotation=45, size=12)
plt.xlabel(xlabel = 'Make', size = 20)
plt.ylabel(ylabel = 'Frequency', size = 20)
plt.title(label = 'Frequency Distribution', size = 20)
# Out:
# Text(0.5, 1.0, 'Frequency Distribution')

# %%
sns.distplot(train_df['Fuel Consumption City (L/100 km)'])
# Out:
# <AxesSubplot:xlabel='Fuel Consumption City (L/100 km)', ylabel='Density'>

# %%
figure = plt.figure(figsize=[15, 7])
train_df.groupby(by=['Fuel Type'])['CO2 Emissions(g/km)'].mean().plot.bar()
plt.xticks(size=12, rotation=0)
plt.grid(b=True)
plt.xlabel(xlabel='Fuel Type', size=14)
plt.ylabel(ylabel='CO2 Emissions(g/km)', size=14)
# Out:
# Text(0, 0.5, 'CO2 Emissions(g/km)')

# %%
figure = plt.figure(figsize=[15, 7])
sns.heatmap(data=train_df.corr(), annot=True)
plt.xticks(size=12, rotation=90)
plt.yticks(size=12)
plt.xlabel(xlabel='Feature Space X', size=14)
plt.ylabel(ylabel='Feature Space Y', size=14)
plt.title(label='Correlation of Features', size=16)
plt.show()

# %%
sns.pairplot(train_df)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              5760 non-null   object
#  1   Model                             5760 non-null   object
#  2   Vehicle Class                     5760 non-null   object
#  3   Engine Size(L)                    5760 non-null   float64
#  4   Cylinders                         5760 non-null   int64
#  5   Transmission                      5760 non-null   object
#  6   Fuel Type                         5760 non-null   object
#  7   Fuel Consumption City (L/100 km)  5760 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   5760 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  5760 non-null   float64
#  10  Fuel Consumption Comb (mpg)       5760 non-null   int64
# ...

# %% [markdown]
# **Using LabelEncoder for Categorical Variables:**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
train_df['Make'] = le.fit_transform(train_df['Make'])
train_df['Model'] = le.fit_transform(train_df['Model'])
train_df['Vehicle Class'] = le.fit_transform(train_df['Vehicle Class'])
train_df['Transmission'] = le.fit_transform(train_df['Transmission'])
train_df['Fuel Type'] = le.fit_transform(train_df['Fuel Type'])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              5760 non-null   int32
#  1   Model                             5760 non-null   int32
#  2   Vehicle Class                     5760 non-null   int32
#  3   Engine Size(L)                    5760 non-null   float64
#  4   Cylinders                         5760 non-null   int64
#  5   Transmission                      5760 non-null   int32
#  6   Fuel Type                         5760 non-null   int32
#  7   Fuel Consumption City (L/100 km)  5760 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   5760 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  5760 non-null   float64
#  10  Fuel Consumption Comb (mpg)       5760 non-null   int64
# ...

# %% [markdown]
# **Checking and treating outliers:**

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              5760 non-null   int32
#  1   Model                             5760 non-null   int32
#  2   Vehicle Class                     5760 non-null   int32
#  3   Engine Size(L)                    5760 non-null   float64
#  4   Cylinders                         5760 non-null   float64
#  5   Transmission                      5760 non-null   int32
#  6   Fuel Type                         5760 non-null   float64
#  7   Fuel Consumption City (L/100 km)  5760 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   5760 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  5760 non-null   float64
#  10  Fuel Consumption Comb (mpg)       5760 non-null   float64
# ...

# %%
df_train.head()
# Out:
#    Make  Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0     9   1669             11             1.4        4.0            15
# 1    13   1161             10             5.8        8.0            25
# 2    28    656              2             3.0        6.0             6
# 3    19   1841              2             5.0        8.0            17
# 4    11    427              2             6.2        8.0             5
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0        2.0                               9.9
# 1        3.0                              15.9
# 2        3.0                              11.8
# 3        1.0                              21.3
# 4        3.0                              18.0
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              7.8                               8.9
# 1                              9.9                              13.2
# ...

# %% [markdown]
# **Train-Test Split:**

# %%
x = df_train.iloc[:, 0:11]
y = df_train['CO2 Emissions(g/km)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state =13)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4608, 11)
# (1152, 11)
# (4608,)
# (1152,)

# %%
from sklearn.linear_model import LinearRegression

# %%
le = LinearRegression()

# %%
le.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
le.score(x_test, y_test)
# Out:
# 0.9181907098070172

# %%
y_test_mean = np.full(len(y_test), y_test.mean())

# %%
y_test.mean()
# Out:
# 249.45659722222223

# %%
r2_score(y_test, y_test_mean)
# Out:
# 0.0

# %%
r2_score(y_test, y_test)
# Out:
# 1.0

# %%
#Predicting on test data
y_pred_test = regressor.predict(x_test)
y_pred_test
# Out:
# array([257.80916667, 275.724     , 342.11      , ..., 252.045     ,
#        278.63      , 294.64347619])

# %%
sns.regplot(y_test,y_pred_test)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
MSE = mean_squared_error(y_test, y_pred_test)
print('MSE for test set is {}'.format(MSE))
# Out:
# MSE for test set is 7.145502037963275

# %%
R2= r2_score(y_test, y_pred_test)
print("R2 score for test set is {}".format(R2))
# Out:
# R2 score for test set is 0.9978020581235459

# %% [markdown]
# **RandomForestRegressor:**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %%
regressor = RandomForestRegressor()

# %%
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
#Predicting on train data
y_pred_train = regressor.predict(x_train)
y_pred_train
# Out:
# array([136.07  , 273.37  , 200.75  , ..., 387.8   , 234.6025, 189.97  ])

# %%
sns.regplot(y_train,y_pred_train)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
MSE = mean_squared_error(y_train, y_pred_train)
print('MSE for train set is {}'.format(MSE))
# Out:
# MSE for train set is 2.433475246698424

# %%
R2= r2_score(y_train, y_pred_train)
print("R2 score for train set is {}".format(R2))
# Out:
# R2 score for train set is 0.9992668790527578

# %%
#Predicting on test data
y_pred_test = regressor.predict(x_test)
y_pred_test
# Out:
# array([257.46      , 275.80666667, 341.66      , ..., 252.1       ,
#        278.28      , 295.3125    ])

# %%
sns.regplot(y_test,y_pred_test)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')

# %% [markdown]
# **Model Evaluation on Test data:**

# %%
MSE = mean_squared_error(y_test, y_pred_test)
print('MSE for test set is {}'.format(MSE))
# Out:
# MSE for test set is 7.096498853362599

# %%
R2= r2_score(y_test, y_pred_test)
print("R2 score for test set is {}".format(R2))
# Out:
# R2 score for test set is 0.9978171314033437

# %% [markdown]
# **Test dataset:**

# %%
test_df.head()
# Out:
#         Make                 Model            Vehicle Class  Engine Size(L)  \
# 0    PORSCHE  Panamera 4 Executive                FULL-SIZE             3.0
# 1        BMW          M6 CABRIOLET               SUBCOMPACT             4.4
# 2        GMC                SIERRA  PICKUP TRUCK - STANDARD             6.2
# 3  CHEVROLET             SILVERADO  PICKUP TRUCK - STANDARD             5.3
# 4     TOYOTA           4Runner 4WD           SUV - STANDARD             4.0
#
#    Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          6          AM8         Z                              12.4
# 1          8          AM7         Z                              17.3
# 2          8           A8         Z                              16.1
# 3          8           A6         X                              14.6
# 4          6          AS5         X                              14.3
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              1625 non-null   object
#  1   Model                             1625 non-null   object
#  2   Vehicle Class                     1625 non-null   object
#  3   Engine Size(L)                    1625 non-null   float64
#  4   Cylinders                         1625 non-null   int64
#  5   Transmission                      1625 non-null   object
#  6   Fuel Type                         1625 non-null   object
#  7   Fuel Consumption City (L/100 km)  1625 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   1625 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  1625 non-null   float64
#  10  Fuel Consumption Comb (mpg)       1625 non-null   int64
# dtypes: float64(4), int64(2), object(5)
# ...

# %%
test_df.isna()
# Out:
#        Make  Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0     False  False          False           False      False         False
# 1     False  False          False           False      False         False
# 2     False  False          False           False      False         False
# 3     False  False          False           False      False         False
# 4     False  False          False           False      False         False
# ...     ...    ...            ...             ...        ...           ...
# 1620  False  False          False           False      False         False
# 1621  False  False          False           False      False         False
# 1622  False  False          False           False      False         False
# 1623  False  False          False           False      False         False
# 1624  False  False          False           False      False         False
#
#       Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
test_df['Make'] = le.fit_transform(test_df['Make'])
test_df['Model'] = le.fit_transform(test_df['Model'])
test_df['Transmission'] = le.fit_transform(test_df['Transmission'])
test_df['Fuel Type'] = le.fit_transform(test_df['Fuel Type'])
test_df['Vehicle Class'] = le.fit_transform(test_df['Vehicle Class'])

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              1625 non-null   int32
#  1   Model                             1625 non-null   int32
#  2   Vehicle Class                     1625 non-null   int32
#  3   Engine Size(L)                    1625 non-null   float64
#  4   Cylinders                         1625 non-null   int64
#  5   Transmission                      1625 non-null   int32
#  6   Fuel Type                         1625 non-null   int32
#  7   Fuel Consumption City (L/100 km)  1625 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   1625 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  1625 non-null   float64
#  10  Fuel Consumption Comb (mpg)       1625 non-null   int64
# dtypes: float64(4), int32(5), int64(2)
# ...

# %%
for col in test_df.iloc[:,3:5].columns:
    print(col)
    sns.boxplot(x = test_df[col], data = test_df)
    plt.show()
# Out:
# Engine Size(L)
# Cylinders

# %%
def Outlier(var):
    for x in var.iloc[:, 3:5].columns:
        Q1 = var[x].quantile(0.25)
        Q3 = var[x].quantile(0.75)
        IQR = Q3-Q1
        Lower = Q1-(1.5*IQR)
        Upper = Q3+(1.5*IQR)
        var.loc[:,x] = np.where(var[x].values > Upper, Upper, var[x].values)
        var.loc[:,x] = np.where(var[x].values < Lower, Lower, var[x].values)
    return var
df_test = Outlier(test_df)

# %%
for col in df_test.iloc[:, 3:5].columns:
    print(col)
    sns.boxplot(x = test_df[col], data = df_test)
    plt.show()
# Out:
# Engine Size(L)
# Cylinders

# %%
for col in test_df.iloc[:,6:].columns:
    print(col)
    sns.boxplot(x = test_df[col], data = test_df)
    plt.show()
# Out:
# Fuel Type
# Fuel Consumption City (L/100 km)
# Fuel Consumption Hwy (L/100 km)
# Fuel Consumption Comb (L/100 km)
# Fuel Consumption Comb (mpg)

# %%
def Outlier(var):
    for x in var.iloc[:, 6:].columns:
        Q1 = var[x].quantile(0.25)
        Q3 = var[x].quantile(0.75)
        IQR = Q3-Q1
        Lower = Q1-(1.5*IQR)
        Upper = Q3+(1.5*IQR)
        var.loc[:,x] = np.where(var[x].values > Upper, Upper, var[x].values)
        var.loc[:,x] = np.where(var[x].values < Lower, Lower, var[x].values)
    return var
df_test = Outlier(test_df)

# %%
for col in df_test.iloc[:, 6:].columns:
    print(col)
    sns.boxplot(x = test_df[col], data = df_test)
    plt.show()
# Out:
# Fuel Type
# Fuel Consumption City (L/100 km)
# Fuel Consumption Hwy (L/100 km)
# Fuel Consumption Comb (L/100 km)
# Fuel Consumption Comb (mpg)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              1625 non-null   int32
#  1   Model                             1625 non-null   int32
#  2   Vehicle Class                     1625 non-null   int32
#  3   Engine Size(L)                    1625 non-null   float64
#  4   Cylinders                         1625 non-null   float64
#  5   Transmission                      1625 non-null   int32
#  6   Fuel Type                         1625 non-null   float64
#  7   Fuel Consumption City (L/100 km)  1625 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   1625 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  1625 non-null   float64
#  10  Fuel Consumption Comb (mpg)       1625 non-null   float64
# dtypes: float64(7), int32(4)
# ...

# %%
test_1 = df_test.iloc[:, 0:]

# %%
predicted_test = regressor.predict(test_1)

# %%
predicted_test
# Out:
# array([252.73066667, 341.28      , 326.395     , ..., 297.32857143,
#        199.91      , 286.37      ])

# %%
test_1['CO2 Predicted'] = predicted_test

# %%
test_1.to_csv('Submission_pred_CO.csv', index = False, header = False)
